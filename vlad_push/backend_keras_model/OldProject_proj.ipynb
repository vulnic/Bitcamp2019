# %%
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
# Out:
# Using TensorFlow backend.

# %%
im = "train_images/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e/images/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e.png"
it = "train_images/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552/images/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.png"

# %%
img = plt.imread(im)
temp = img

arr = np.array(temp)
arr.shape
# Out:
# (256, 320, 4)

# %%
masks = np.array(pd.read_csv("train_masks.csv"))
rowsPerPic = np.array([0])
picNames = np.array(["00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552"])
count = 0
check = True

while check:
    if(rowsPerPic[count] == 31889):
        check = False
    
    elif(masks[rowsPerPic[count]][0] != picNames[count]):
        count += 1;
        rowsPerPic = np.append(rowsPerPic, rowsPerPic[count-1])
        picNames = np.append(picNames, masks[rowsPerPic[count]][0])
    
    else:
        rowsPerPic[count] += 1

# %%
imgplot = plt.imshow(temp)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imsave("img.jpg",img)
